# %%
import torch

# %%
sample=torch.tensor([[12,4],[5,6]])
#cria um array tensor
sample
# Out:
# tensor([[12,  4],
#         [ 5,  6]])

# %%
x= torch.tensor([[1],[4]])
x.shape
#mostra o tamanho do tensor
# Out:
# torch.Size([2, 1])

# %%
y= torch.tensor([[4],[8]])
y.shape
#mostra o tamanho do tensor
# Out:
# torch.Size([2, 1])

# %%
import plotly.graph_objects as go
import plotly.offline as pyo

a = torch.tensor([[[1, 2], [3, 4]], [[5, 6], [7, 8]]])
# cria uma matriz 2x2

x_vals = []
y_vals = []
z_vals = []
for i in range(a.shape[0]):
    for j in range(a.shape[1]):
        for k in range(a.shape[2]):
            x_vals.append(i)
            y_vals.append(j)
            z_vals.append(k)
# for aninhados criando um objeto tridimensional
trace = go.Scatter3d(
    x=x_vals,
    y=y_vals,
    z=z_vals,
    mode='markers',
    marker=dict(
        size=5,
        color=a.flatten(),
        colorscale='Viridis',
        opacity=0.8
    )
)

layout = go.Layout(
    margin=dict(l=0, r=0, b=0, t=0),
    scene=dict(
        xaxis=dict(title='dimensão 1'),
        yaxis=dict(title='dimensão 2'),
        zaxis=dict(title='dimensão 3')
    )
)
# cria um objeto 3d, para visualizar o tensor
fig = go.Figure(data=[trace],layout=layout)
pyo.plot(fig, filename='tensor_plot.html')
# Out:
# 'tensor_plot.html'
