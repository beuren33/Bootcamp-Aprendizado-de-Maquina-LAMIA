# %%
import cv2 as cv
import matplotlib.pyplot as plt
import numpy as np

# %%
img = cv.imread('/home/beuren/Documentos/Bootcamp-LAMIA/card21/course/cnn/image.png')

# %%
plt.imshow(cv.cvtColor(img, cv.COLOR_BGR2RGB))
# mostra a imagem colorida converto ela para RGB

# %%
plt.imshow(cv.cvtColor(img, cv.COLOR_BGR2GRAY), cmap='gray')
# imagem cinza

# %%
img_menor = cv.resize(img, (50, 50))
# mudando o tamnho podemos manipular ostamnho dos pixels assim ela fica borrada
plt.imshow(cv.cvtColor(img_menor, cv.COLOR_BGR2RGB))

# %%
plt.imshow(img[100:200,:], cmap='gray')
# utilizando o slice podemos manipular o tamanho da imagem cortando partes desnecessarias
